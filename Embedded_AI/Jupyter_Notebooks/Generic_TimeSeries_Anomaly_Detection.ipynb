# %% [markdown]
# # Generic Time-Series Anomaly Detection using Autoencoder
#
# Embedded & TinyML Friendly Student Template

# %% [markdown]
# ## Objective
# This notebook demonstrates a generic anomaly detection approach for time-series sensor data using an autoencoder.

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

import pandas as pd


from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, classification_report

import tensorflow as tf
from tensorflow.keras import layers, models

# %% [markdown]
# ## Configuration (Edit Only This Section)

# %% [markdown]
# •	Tensors: Models operate using tensors, essentially lists or arrays of numbers. A 1D tensor is a vector, a 2D tensor is a matrix, and a single number is a scalar.
#
# •	Feature Generation: Raw data, often collected as time series with inconsistent intervals, must be prepared for the model. A common technique is windowing, where a chunk of time is defined, and values within that window are combined (e.g., by averaging) to create a single set of input features.
#
# •	Normalization: For the training algorithm to work effectively, feature values must be scaled, ideally into a similar range (like 0 to 1). For example, 8-bit image data (0-255) is normalized by multiplying values by 1/255.

# %% [markdown]
# ## Load Sensor Data

# %%
normal_df = pd.read_csv("normal_data.csv")
abnormal_df = pd.read_csv("abnormal_data.csv")

print("Normal shape   :", normal_df.shape)
print("Abnormal shape :", abnormal_df.shape)
# Out:
# Normal shape   : (600, 3)
# Abnormal shape : (600, 3)

# %% [markdown]
# Keeping only [current, vibration] data removing time column

# %%
normal_features = normal_df.drop(columns=['time'])
abnormal_features = abnormal_df.drop(columns=['time'])
#printing shape after dropping the 'time' column
print(normal_features.shape)
print(abnormal_features.shape)
# Out:
# (600, 2)
# (600, 2)

# %% [markdown]
# Autoencoder is trained ONLY on normal data.
#
# 3️⃣ Feature Selection (VERY IMPORTANT)
#
# Keep only numeric sensor features.

# %%
features = normal_features.columns.tolist()
print("Features used:", features)
# Out:
# Features used: ['Irms', 'VibrationMag']

# %% [markdown]
# Confirming Final Table Data

# %%
normal_features.head()
# Out:
#        Irms  VibrationMag
# 0  0.303685      0.036216
# 1  0.300606      0.056023
# 2  0.307243      0.069711
# 3  0.308459      0.075328
# 4  0.309300      0.048889

# %% [markdown]
# ## Sliding Window Creation in not Required here as Anomalies cause instantaneous deviations, not slow wearout

# %% [markdown]
# ## Normalization and Scalar Selection

# %% [markdown]
# This scaler must be reused later on STM32 logic (mean & std).
#
# // Extracted from Python scaler
# #define IRMS_MEAN        2.34f
# #define IRMS_STD         0.15f
# #define VIB_MEAN         0.012f
# #define VIB_STD          0.003f
#
# float irms = read_current_sensor();
# float vib  = read_vibration_sensor();
#
# // StandardScaler normalization
# float irms_norm = (irms - IRMS_MEAN) / IRMS_STD;
# float vib_norm  = (vib  - VIB_MEAN)  / VIB_STD;
#
# // Fill AI input buffer
# ((float*)in_data)[0] = irms_norm;
# ((float*)in_data)[1] = vib_norm;

# %%
scaler = StandardScaler()

X_train = scaler.fit_transform(normal_features)
X_test_normal = scaler.transform(normal_features)
X_test_abnormal = scaler.transform(abnormal_features)

# %%
print("Scaler mean :", scaler.mean_)
print("Scaler std  :", scaler.scale_)
# Out:
# Scaler mean : [0.29274811 0.04952801]
# Scaler std  : [0.0287444 0.0123394]

# %% [markdown]
# ## Autoencoder Model

# %%
#to Reset the model if trained with same data multiple times to avoid over fitting
tf.keras.backend.clear_session()
# Out:
# WARNING:tensorflow:From c:\Users\z665059\OneDrive - ZF Friedrichshafen AG\Documents\my_project_temperature_classification\venv1\Lib\site-packages\keras\src\backend\common\global_state.py:82: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
# WARNING:tensorflow:From c:\Users\z665059\OneDrive - ZF Friedrichshafen AG\Documents\my_project_temperature_classification\venv1\Lib\site-packages\keras\src\backend\common\global_state.py:82: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.

# %%
N = X_train.shape[1]  # number of features (2)

autoencoder = models.Sequential([
    layers.Dense(8, activation='relu', input_shape=(N,)),
    layers.Dense(4, activation='relu'),
    layers.Dense(8, activation='relu'),
    layers.Dense(N)
])

autoencoder.compile(
    optimizer='adam',
    loss='mse'
)

autoencoder.summary()
# Out:
# c:\Users\z665059\OneDrive - ZF Friedrichshafen AG\Documents\my_project_temperature_classification\venv1\Lib\site-packages\keras\src\layers\core\dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 8)              │            24 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 4)              │            36 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 8)              │            40 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 2)              │            18 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 118 (472.00 B)
#  Trainable params: 118 (472.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Training only on Normal Data

# %%
history = autoencoder.fit(
    X_train, X_train,
    epochs=50,
    batch_size=32,
    validation_split=0.1,
    shuffle=True,
    verbose=1
)
# Out:
# Epoch 1/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.0866 - val_loss: 1.0384
# Epoch 2/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.0371 - val_loss: 0.9995
# Epoch 3/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9806 - val_loss: 0.9370
# Epoch 4/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.9030 - val_loss: 0.8704
# Epoch 5/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.8296 - val_loss: 0.8088
# Epoch 6/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.7617 - val_loss: 0.7499
# Epoch 7/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.7011 - val_loss: 0.6961
# Epoch 8/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.6497 - val_loss: 0.6495
# Epoch 9/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.6060 - val_loss: 0.6099
# Epoch 10/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.5722 - val_loss: 0.5778
# Epoch 11/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.5441 - val_loss: 0.5504
# Epoch 12/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.5209 - val_loss: 0.5266
# Epoch 13/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.4991 - val_loss: 0.4977
# Epoch 14/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4743 - val_loss: 0.4637
# Epoch 15/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.4422 - val_loss: 0.4191
# Epoch 16/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4015 - val_loss: 0.3633
# Epoch 17/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.3504 - val_loss: 0.3046
# Epoch 18/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2938 - val_loss: 0.2434
# Epoch 19/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2356 - val_loss: 0.1852
# Epoch 20/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1831 - val_loss: 0.1380
# Epoch 21/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1385 - val_loss: 0.1029
# Epoch 22/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1018 - val_loss: 0.0789
# Epoch 23/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0764 - val_loss: 0.0611
# Epoch 24/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0572 - val_loss: 0.0487
# Epoch 25/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0440 - val_loss: 0.0391
# Epoch 26/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0341 - val_loss: 0.0327
# Epoch 27/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0276 - val_loss: 0.0279
# Epoch 28/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0230 - val_loss: 0.0245
# Epoch 29/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0195 - val_loss: 0.0210
# Epoch 30/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0167 - val_loss: 0.0184
# Epoch 31/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0146 - val_loss: 0.0163
# Epoch 32/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0130 - val_loss: 0.0149
# Epoch 33/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0117 - val_loss: 0.0135
# Epoch 34/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0106 - val_loss: 0.0128
# Epoch 35/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0097 - val_loss: 0.0117
# Epoch 36/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0090 - val_loss: 0.0112
# Epoch 37/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0084 - val_loss: 0.0105
# Epoch 38/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0079 - val_loss: 0.0103
# Epoch 39/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0075 - val_loss: 0.0097
# Epoch 40/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0071 - val_loss: 0.0092
# Epoch 41/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0068 - val_loss: 0.0088
# Epoch 42/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0065 - val_loss: 0.0084
# Epoch 43/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0062 - val_loss: 0.0081
# Epoch 44/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0060 - val_loss: 0.0078
# Epoch 45/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0058 - val_loss: 0.0075
# Epoch 46/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0056 - val_loss: 0.0071
# Epoch 47/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0054 - val_loss: 0.0069
# Epoch 48/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0052 - val_loss: 0.0065
# Epoch 49/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0049 - val_loss: 0.0063
# Epoch 50/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0047 - val_loss: 0.0060

# %% [markdown]
# ## Plot Training Loss

# %%
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.xlabel("Epoch")
plt.ylabel("MSE Loss")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ## Reconstruction Error Function

# %%
def reconstruction_error(model, data):
    recon = model.predict(data)
    return np.mean(np.square(data - recon), axis=1)

# %% [markdown]
# On STM32, you will compute exactly the same thing:
#
# error = mean((input[i] - output[i])²)
#
#
# Then:
#
# if (error > THRESHOLD)
#     anomaly = 1;
# else
#     anomaly = 0;

# %% [markdown]
# ## Compute Errors

# %%
err_normal = reconstruction_error(autoencoder, X_test_normal)
err_abnormal = reconstruction_error(autoencoder, X_test_abnormal)
# Out:
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %% [markdown]
# ## Threshold Selection

# %%
threshold = np.mean(err_normal) + 3 * np.std(err_normal)
print("Anomaly Threshold:", threshold)
# Out:
# Anomaly Threshold: 0.021783008666265227

# %% [markdown]
# ## Visualize Error Distribution (Very Important)

# %%
plt.hist(err_normal, bins=50, alpha=0.6, label="Normal")
plt.hist(err_abnormal, bins=50, alpha=0.6, label="Abnormal")
plt.axvline(threshold, color='r', linestyle='--', label="Threshold")
plt.xlabel("Reconstruction Error")
plt.ylabel("Count")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ## Binary Evaluation

# %%
y_true = np.concatenate([
    np.zeros(len(err_normal)),
    np.ones(len(err_abnormal))
])

y_pred = np.concatenate([
    err_normal > threshold,
    err_abnormal > threshold
]).astype(int)

# %% [markdown]
# ## Confusion Metrics

# %%
print("Confusion Matrix:")
print(confusion_matrix(y_true, y_pred))

print("\nClassification Report:")
print(classification_report(
    y_true, y_pred,
    target_names=["Normal", "Anomaly"]
))
# Out:
# Confusion Matrix:
# [[589  11]
#  [  0 600]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#       Normal       1.00      0.98      0.99       600
#      Anomaly       0.98      1.00      0.99       600
#
#     accuracy                           0.99      1200
#    macro avg       0.99      0.99      0.99      1200
# weighted avg       0.99      0.99      0.99      1200

# %% [markdown]
# ## Testing on New Data

# %%
sample = abnormal_features.iloc[0].values.reshape(1, -1)
sample_scaled = scaler.transform(sample)

error = reconstruction_error(autoencoder, sample_scaled)[0]

print("Reconstruction Error:", error)

if error > threshold:
    print("⚠️ Anomaly detected")
else:
    print("✅ Normal operation")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# Reconstruction Error: 2.9814636025240295
# ⚠️ Anomaly detected
# c:\Users\z665059\OneDrive - ZF Friedrichshafen AG\Documents\my_project_temperature_classification\venv1\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %% [markdown]
# ## Convert to TFLITE

# %%
autoencoder.save("autoencoder_model.keras")

converter = tf.lite.TFLiteConverter.from_keras_model(autoencoder)
converter.optimizations = [tf.lite.Optimize.DEFAULT]

tflite_model = converter.convert()

with open("autoencoder_anomaly.tflite", "wb") as f:
    f.write(tflite_model)

print("TFLite model saved successfully")
print("Model size:", len(tflite_model), "bytes")
# Out:
# INFO:tensorflow:Assets written to: C:\Users\z665059\AppData\Local\Temp\tmput0tmnoy\assets
# INFO:tensorflow:Assets written to: C:\Users\z665059\AppData\Local\Temp\tmput0tmnoy\assets
# Saved artifact at 'C:\Users\z665059\AppData\Local\Temp\tmput0tmnoy'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 2), dtype=tf.float32, name='keras_tensor')
# Output Type:
#   TensorSpec(shape=(None, 2), dtype=tf.float32, name=None)
# Captures:
#   2938617846416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2938617839696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2938917523472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2938921203664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2938617852752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2938617852368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2938617853904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2938608511568: TensorSpec(shape=(), dtype=tf.resource, name=None)
# TFLite model saved successfully
# Model size: 2728 bytes

# %% [markdown]
# Testing on new sensor collected data

# %%
#extract data from csv (time column removed data)
new_features = pd.read_csv("new_data_normal.csv")
#scaling and noramlization same as the one used during training
X_new = scaler.transform(new_features)
#run autoencoder on new data
recon = autoencoder.predict(X_new)
#compute the reconstrction error
err_new = np.mean(np.square(X_new - recon), axis=1)
#Apply the Threshold (Decision Logic)
is_anomaly = err_new > threshold
#Inspect Results (Text Output)
results = new_features.copy()
results['reconstruction_error'] = err_new
results['anomaly'] = is_anomaly

print(results)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
#         Irms  VibrationMag  reconstruction_error  anomaly
# 0   0.324017      0.064350              0.005640    False
# 1   0.325239      0.049451              0.005949    False
# 2   0.318235      0.073809              0.003278    False
# 3   0.313600      0.096464              0.037581     True
# 4   0.310440      0.085509              0.013245    False
# 5   0.311010      0.062510              0.003588    False
# 6   0.305683      0.091374              0.022963     True
# 7   0.295435      0.071230              0.004812    False
# 8   0.302461      0.053332              0.007367    False
# 9   0.306459      0.085305              0.012144    False
# 10  0.301855      0.078205              0.005135    False
# 11  0.297504      0.074557              0.003907    False
# 12  0.290650      0.066195              0.008619    False
# 13  0.303179      0.074366              0.005159    False
# 14  0.294571      0.078609              0.003943    False
# 15  0.290806      0.095612              0.032195     True
# 16  0.286761      0.087029              0.011979    False
# 17  0.287199      0.082880              0.006215    False
# 18  0.290204      0.075506              0.002531    False
# 19  0.287507      0.071680              0.003100    False

# %% [markdown]
# Visualize New Data Errors (Highly Recommended)

# %%
plt.figure(figsize=(8,4))
plt.plot(err_new, label="New data error")
plt.axhline(threshold, color='red', linestyle='--', label="Threshold")
plt.xlabel("Sample index")
plt.ylabel("Reconstruction Error")
plt.title("Anomaly Detection on New Data")
plt.legend()
plt.grid()
plt.show()

# %%
sample = new_features.iloc[1].values.reshape(1, -1)
sample_scaled = scaler.transform(sample)
#print(sample_scaled)
recon = autoencoder.predict(sample_scaled)
print("recon",recon)
error = np.mean((sample_scaled - recon) ** 2)

print("Reconstruction error:", error)

if error > threshold:
    print("⚠️ Anomaly detected")
else:
    print("✅ Normal operation")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# recon [[ 1.0311626  -0.05164683]]
# Reconstruction error: 0.00594889121361844
# ✅ Normal operation
# c:\Users\z665059\OneDrive - ZF Friedrichshafen AG\Documents\my_project_temperature_classification\venv1\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
